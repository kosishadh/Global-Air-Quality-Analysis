# %% [markdown]
# # For the whole dataframe

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv("data.csv")
print(df.to_string)
# Out:
# <bound method DataFrame.to_string of      Country       City Continent    Month  AQI  \
# 0      India  New Delhi      Asia  2024-01  238
# 1      India  New Delhi      Asia  2024-02  221
# 2      India  New Delhi      Asia  2024-03  185
# 3      India  New Delhi      Asia  2024-04  139
# 4      India  New Delhi      Asia  2024-05  167
# ..       ...        ...       ...      ...  ...
# 475  Vietnam      Hanoi      Asia  2024-08  140
# 476  Vietnam      Hanoi      Asia  2024-09  100
# 477  Vietnam      Hanoi      Asia  2024-10  132
# 478  Vietnam      Hanoi      Asia  2024-11  119
# 479  Vietnam      Hanoi      Asia  2024-12  179
#
#                        AQI_Category  PM2.5   PM10    NO2   SO2    CO    O3  \
# 0                    Very Unhealthy  100.7  161.1   32.3  12.6  0.79  70.6
# 1                    Very Unhealthy   93.0  121.9  128.9  46.6  1.52  22.7
# 2                         Unhealthy   72.7  105.1   71.5   9.1  1.61  35.6
# ...

# %% [markdown]
# # For data types of different rows

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv("data.csv")
print(df.dtypes)
# Out:
# Country                   str
# City                      str
# Continent                 str
# Month                     str
# AQI                     int64
# AQI_Category              str
# PM2.5                 float64
# PM10                  float64
# NO2                   float64
# SO2                   float64
# CO                    float64
# O3                    float64
# Dominant_Pollutant        str
# dtype: object

# %% [markdown]
# # For checking value of rows

# %%
import pandas as pd
df = pd.read_csv("data.csv")
print(len(df))
# Out:
# 480

# %%
import pandas as pd
df = pd.read_csv('data.csv')
row_count = df.shape[0]
print(row_count)
# Out:
# 480

# %% [markdown]
# # For checking number of columns

# %%
import pandas as pd
df = pd.read_csv("data.csv")
print(df.columns)
print(df.shape[1])
# Out:
# Index(['Country', 'City', 'Continent', 'Month', 'AQI', 'AQI_Category', 'PM2.5',
#        'PM10', 'NO2', 'SO2', 'CO', 'O3', 'Dominant_Pollutant'],
#       dtype='str')
# 13

# %% [markdown]
# # For cities

# %%
import pandas as pd
df = pd.read_csv("data.csv")
cities = df["City"].value_counts()
print(cities)
print(len(cities))
# Out:
# City
# New Delhi       12
# Lahore          12
# Dhaka           12
# Beijing         12
# Ulaanbaatar     12
# Cairo           12
# Jakarta         12
# Mumbai          12
# Mexico City     12
# Lagos           12
# Bangkok         12
# Shanghai        12
# Riyadh          12
# Los Angeles     12
# Istanbul        12
# Sao Paulo       12
# Moscow          12
# Seoul           12
# Rome            12
# Madrid          12
# Paris           12
# Johannesburg    12
# London          12
# Tokyo           12
# New York        12
# Berlin          12
# Toronto         12
# Singapore       12
# Sydney          12
# Reykjavik       12
# Wellington      12
# Stockholm       12
# Zurich          12
# Helsinki        12
# Oslo            12
# Vancouver       12
# Nairobi         12
# Buenos Aires    12
# Kathmandu       12
# Hanoi           12
# Name: count, dtype: int64
# 40

# %% [markdown]
# # For Countries

# %%
import pandas as pd
df = pd.read_csv("data.csv")
countries = df["Country"].value_counts()
print(countries)
print(len(countries))
# Out:
# Country
# India             24
# China             24
# United States     24
# Canada            24
# Pakistan          12
# Bangladesh        12
# Mongolia          12
# Egypt             12
# Indonesia         12
# Mexico            12
# Nigeria           12
# Thailand          12
# Saudi Arabia      12
# Turkey            12
# Brazil            12
# Russia            12
# South Korea       12
# Italy             12
# Spain             12
# France            12
# South Africa      12
# United Kingdom    12
# Japan             12
# Germany           12
# Singapore         12
# Australia         12
# Iceland           12
# New Zealand       12
# Sweden            12
# Switzerland       12
# Finland           12
# Norway            12
# Kenya             12
# Argentina         12
# Nepal             12
# Vietnam           12
# Name: count, dtype: int64
# 36

# %% [markdown]
# # For missing values

# %%
import pandas as pd
df = pd.read_csv("data.csv")
miss = df.isnull().sum()
print(miss)
# Out:
# Country               0
# City                  0
# Continent             0
# Month                 0
# AQI                   0
# AQI_Category          0
# PM2.5                 0
# PM10                  0
# NO2                   0
# SO2                   0
# CO                    0
# O3                    0
# Dominant_Pollutant    0
# dtype: int64

# %% [markdown]
# # Find minimum PM2.5

# %%
import pandas as pd
df = pd.read_csv("data.csv")
print(df.loc[df["PM2.5"].idxmin(),['Country','PM2.5']])
# Out:
# Country    Iceland
# PM2.5          3.4
# Name: 354, dtype: object

# %% [markdown]
# # Find maximum PM2.5

# %%
import pandas as pd
df = pd.read_csv("data.csv")
print(df.loc[df["PM2.5"].idxmax(),['Country','PM2.5']])
# Out:
# Country    Pakistan
# PM2.5         108.4
# Name: 12, dtype: object

# %% [markdown]
# # Mean of PM2.5

# %%
import pandas as pd
df = pd.read_csv("data.csv")
print(df["PM2.5"].mean())
# Out:
# 31.137083333333337

# %% [markdown]
# # Median of PM2.5

# %%
import pandas as pd
df = pd.read_csv("data.csv")
print(df["PM2.5"].median())
# Out:
# 25.65

# %% [markdown]
# # Standard Deviation

# %%
import pandas as pd
df = pd.read_csv("data.csv")
print(df["PM2.5"].std())
# Out:
# 21.159836098351903

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
df = pd.read_csv("data.csv")
print(df.isnull().sum())
# Out:
# Country               0
# City                  0
# Continent             0
# Month                 0
# AQI                   0
# AQI_Category          0
# PM2.5                 0
# PM10                  0
# NO2                   0
# SO2                   0
# CO                    0
# O3                    0
# Dominant_Pollutant    0
# dtype: int64

# %% [markdown]
# # 10  most polluted cities

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("data.csv")
avg_pm2 = df.groupby("City")["PM2.5"].mean()
top_10_city = avg_pm2.sort_values(ascending=False).head(10)
print(top_10_city)
top_10_city.plot(kind='barh', color="Red", edgecolor = "black")
plt.xlabel('Average PM 2.5')
plt.show()
# Out:
# City
# Lahore         79.058333
# New Delhi      75.558333
# Ulaanbaatar    69.441667
# Dhaka          69.266667
# Kathmandu      62.275000
# Cairo          56.083333
# Hanoi          51.875000
# Beijing        48.083333
# Jakarta        46.050000
# Riyadh         40.800000
# Name: PM2.5, dtype: float64

# %% [markdown]
# # Highest Average Pollution

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('data.csv')
avg_pm2 = df.groupby('Country')['PM2.5'].mean()
top_country = avg_pm2.sort_values(ascending=False).head(10)
print(top_country)
top_country.plot(kind='barh')
plt.xlabel('PM2.5')
plt.show()
# Out:
# Country
# Pakistan        79.058333
# Mongolia        69.441667
# Bangladesh      69.266667
# Nepal           62.275000
# India           58.129167
# Egypt           56.083333
# Vietnam         51.875000
# Indonesia       46.050000
# China           43.108333
# Saudi Arabia    40.800000
# Name: PM2.5, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("data.csv")
pm25 = df.groupby("Country")["PM2.5"].mean()
pm25.plot(kind = "barh", color = "red", edgecolor="black")
plt.tight_layout()
plt.xlabel("Average PM2.5 of Country")
plt.show()

# %% [markdown]
# # PM2.5 vs PM10

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("data.csv")

plt.scatter(df["PM2.5"] , df["PM10"],alpha=0.5)
plt.xlabel('PM2.5')
plt.ylabel('PM10')
plt.title('PM10 vs PM2.5')
plt.show()

correlation= np.corrcoef(df["PM2.5"] , df["PM10"])[0,1]
print("Correlation:", correlation)
# Out:
# Correlation: 0.9864700746138125

# %% [markdown]
# PM2.5 and PM10 have a strong positive correlation of 0.82, indicating that locations with higher PM10 concentrations tend to also have higher PM2.5 concentrations.

# %% [markdown]
# # PM2.5 vs NO2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')
x=df["PM2.5"]
y=df["NO2"]

plt.scatter(x,y,alpha=0.5)
plt.xlabel("PM2.5")
plt.ylabel("NO2")
plt.title("PM2.5 vs NO2")
plt.show()

correlation = np.corrcoef(x,y)[0,1]
print("Correlation:", correlation)
# Out:
# Correlation: 0.7505251469431495
